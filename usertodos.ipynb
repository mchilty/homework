# %% [markdown]
# ## ~~2~~ 3 different solutions to a JSONPlaceholder code challenge
#
# **Challenge**:
#
# "You will be working with the JSONPlaceholder API, a fake online REST
# API used for testing and prototyping.
#
# Your task is to integrate two endpoints from this API. The first
# endpoint is the 'Todos' API (https://jsonplaceholder.typicode.com/todos), and the second is the 'Users' API (https://jsonplaceholder.typicode.com/users). For each todo
# item, you need to identify the associated user and retrieve details about both the user and the todo.
#
# To accomplish this, you will be querying the 'Todos' endpoint to get a
# list of todo items.
#
# For each todo item, use the 'userId' to query the 'Users' endpoint and
# retrieve the corresponding user details.
#
# Your goal is to combine the information from these two sources and
# format the output as a JSON object like the example below:
#
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle":
# "delectus aut autem", "completed": false}
#
# Note: For this exercise, please refrain from using AI tools. However,
# feel free to use Google for syntax reference or any other
# programming-related queries.
#
# Useful URLs:
#
# Todos API: https://jsonplaceholder.typicode.com/todos
#
# Users API: https://jsonplaceholder.typicode.com/users
#
# Specific User API (example): https://jsonplaceholder.typicode.com/users/1
#
# The focus of this task is on your ability to work with APIs, process JSON data, and effectively combine information from multiple sources."
#
#
#
#
# ### Approach 1
#   * adheres to the guidance provided by the challenge
#
#   * uses userId from /todos to query /users in 205 API requests (an observation, not a judgment)
#
# ### Approach 2
#   * does not adhere to approach described in the challenge
#
#   * uses /users and /todos API endpoints in 2 API requests
#
#   * data is matched without performing any subsequent API requests
#
# ### Approach 3
#   * does not adhere to approach described in the challenge
#
#   * uses a published API endpoint that is related to the "Specific User API (example)" - manual dorking of this additional path was very easy because /users/1/todos is a likely possible path. This discovery preceded reading the API guide published at https://jsonplaceholder.typicode.com/guide/
#
#   * uses /users and todos data /users/1/todos in 12 API requests

# %% [markdown]
# #### All approaches use the following block for configuration and to fetch the initial JSON responses for /users and /todos:

# %%
import json
import os
import requests

os.environ['REQUESTS_CA_BUNDLE'] = "/Users/mchilty/burpCAcert.pem"
proxies = {"http": "http://127.0.0.1:8080", "https": "http://127.0.0.1:8080"}
headers = {'User-Agent': 'mchilty-0.1'}

users_url = ("https://jsonplaceholder.typicode.com/users")
todos_url = ("https://jsonplaceholder.typicode.com/todos")
users_todos_url = ("https://jsonplaceholder.typicode.com/users/$id/todos")

users_response = requests.get(users_url, headers=headers, proxies=proxies)
todos_response = requests.get(todos_url, headers=headers, proxies=proxies)

users_response_data = users_response.json()
todos_response_data = todos_response.json()

print("Using the following API endpoints:")
print(users_url)
print(todos_url)
print(users_todos_url)
# Out:
# Using the following API endpoints:
# https://jsonplaceholder.typicode.com/users
# https://jsonplaceholder.typicode.com/todos
# https://jsonplaceholder.typicode.com/users/$id/todos

# %% [markdown]
# **Approach 1:**

# %%
#!/usr/local/bin/python3
#
#
#mchilty@gmail.com 
#
#Collects and harmonizes oddball Latin homework completion status using 2 different approaches from:
#
#https://jsonplaceholder.typicode.com/users
#https://jsonplaceholder.typicode.com/todos
#https://jsonplaceholder.typicode.com/users/1
#
#
#Output example:
#{"userName": "Bret", "email": "Sincere@april.biz", "todoTitle":"delectus aut autem", "completed": false}
#
#configure the proxy as suits your needs or remove related arguments
#
#

import json
import os
import requests

os.environ['REQUESTS_CA_BUNDLE'] = "/Users/mchilty/burpCAcert.pem"
proxies = {"http": "http://127.0.0.1:8080", "https": "http://127.0.0.1:8080"}
headers = {'User-Agent': 'mchilty-0.1'}

users_url = ("https://jsonplaceholder.typicode.com/users")
todos_url = ("https://jsonplaceholder.typicode.com/todos")
users_todos_url = ("https://jsonplaceholder.typicode.com/users/$id/todos")

users_response = requests.get(users_url, headers=headers, proxies=proxies)
todos_response = requests.get(todos_url, headers=headers, proxies=proxies)

users_response_data = users_response.json()
todos_response_data = todos_response.json()

print("Using the following API endpoints:")
print(users_url)
print(todos_url)
print(users_todos_url)
print()


#
#follows recommended approach provided in challenge
#uses data found in /todos and queries or fetches related data from the user's profile
#
todos_extract = {}
for todo in todos_response_data:
		userId = (todo['userId'])
		title = (todo['title'])
		completed = (todo['completed'])
		users_bio_url = (users_url + "/" + str(todo['userId']))
		users_bio_response = requests.get(users_bio_url, headers=headers, proxies=proxies) 
		users_bio_response_data = users_bio_response.json()
		
		username = (users_bio_response_data['username'])
		email = (users_bio_response_data['email'])
		
		todos_extract['userName'] = username
		todos_extract['email'] = email
		todos_extract['todoTitle'] = title
		todos_extract['completed'] = completed
		todos_extract_json_data = json.dumps(todos_extract)	
		print(todos_extract_json_data)
		
print()
print("################")
print()
# Out:
# Using the following API endpoints:
# https://jsonplaceholder.typicode.com/users
# https://jsonplaceholder.typicode.com/todos
# https://jsonplaceholder.typicode.com/users/$id/todos
#
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "delectus aut autem", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "quis ut nam facilis et officia qui", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "fugiat veniam minus", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "et porro tempora", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "laboriosam mollitia et enim quasi adipisci quia provident illum", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "qui ullam ratione quibusdam voluptatem quia omnis", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "illo expedita consequatur quia in", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "quo adipisci enim quam ut ab", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "molestiae perspiciatis ipsa", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "illo est ratione doloremque quia maiores aut", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "vero rerum temporibus dolor", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "ipsa repellendus fugit nisi", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "et doloremque nulla", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "repellendus sunt dolores architecto voluptatum", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "ab voluptatum amet voluptas", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "accusamus eos facilis sint et aut voluptatem", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "quo laboriosam deleniti aut qui", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "dolorum est consequatur ea mollitia in culpa", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "molestiae ipsa aut voluptatibus pariatur dolor nihil", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "ullam nobis libero sapiente ad optio sint", "completed": true}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "suscipit repellat esse quibusdam voluptatem incidunt", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "distinctio vitae autem nihil ut molestias quo", "completed": true}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "et itaque necessitatibus maxime molestiae qui quas velit", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "adipisci non ad dicta qui amet quaerat doloribus ea", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "voluptas quo tenetur perspiciatis explicabo natus", "completed": true}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "aliquam aut quasi", "completed": true}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "veritatis pariatur delectus", "completed": true}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "nesciunt totam sit blanditiis sit", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "laborum aut in quam", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis", "completed": true}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "repudiandae totam in est sint facere fuga", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "earum doloribus ea doloremque quis", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "sint sit aut vero", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "porro aut necessitatibus eaque distinctio", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "repellendus veritatis molestias dicta incidunt", "completed": true}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "excepturi deleniti adipisci voluptatem et neque optio illum ad", "completed": true}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "sunt cum tempora", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "totam quia non", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "doloremque quibusdam asperiores libero corrupti illum qui omnis", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "tot
"completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "sed ut vero sit molestiae", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "rerum ex veniam mollitia voluptatibus pariatur", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "consequuntur aut ut fugit similique", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "dignissimos quo nobis earum saepe", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "quis eius est sint explicabo", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "numquam repellendus a magnam", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "ipsam aperiam voluptates qui", "completed": false}
#
# ################

# %% [markdown]
# **Appoach 2:**

# %%
#!/usr/local/bin/python3
#
#
#mchilty@gmail.com 
#
#Collects and harmonizes oddball Latin homework completion status using 2 different approaches from:
#
#https://jsonplaceholder.typicode.com/users
#https://jsonplaceholder.typicode.com/todos
#https://jsonplaceholder.typicode.com/users/1
#
#
#Output example:
#{"userName": "Bret", "email": "Sincere@april.biz", "todoTitle":"delectus aut autem", "completed": false}
#
#configure the proxy as suits your needs or remove related arguments
#
#

import json
import os
import requests

os.environ['REQUESTS_CA_BUNDLE'] = "/Users/mchilty/burpCAcert.pem"
proxies = {"http": "http://127.0.0.1:8080", "https": "http://127.0.0.1:8080"}
headers = {'User-Agent': 'mchilty-0.1'}

users_url = ("https://jsonplaceholder.typicode.com/users")
todos_url = ("https://jsonplaceholder.typicode.com/todos")
users_todos_url = ("https://jsonplaceholder.typicode.com/users/$id/todos")

users_response = requests.get(users_url, headers=headers, proxies=proxies)
todos_response = requests.get(todos_url, headers=headers, proxies=proxies)

users_response_data = users_response.json()
todos_response_data = todos_response.json()

print("Using the following API endpoints:")
print(users_url)
print(todos_url)
print(users_todos_url)
print()
#
#uses the data returned by /todos and /users without using subsequent API requests
#
another_todos_extract = {}
for user in users_response_data:
		username = (user['username'])
		email = (user['email'])

		for todo in todos_response_data:
				title = (todo['title'])
				completed = (todo['completed'])
				
				if (todo['userId']) == (user['id']):
					another_todos_extract['userName'] = username
					another_todos_extract['email'] = email
					another_todos_extract['todoTitle'] = title
					another_todos_extract['completed'] = completed
					another_todos_extract_json_data = json.dumps(another_todos_extract)	
					print(another_todos_extract_json_data)

print()
print("################")
print()
# Out:
# Using the following API endpoints:
# https://jsonplaceholder.typicode.com/users
# https://jsonplaceholder.typicode.com/todos
# https://jsonplaceholder.typicode.com/users/$id/todos
#
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "delectus aut autem", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "quis ut nam facilis et officia qui", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "fugiat veniam minus", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "et porro tempora", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "laboriosam mollitia et enim quasi adipisci quia provident illum", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "qui ullam ratione quibusdam voluptatem quia omnis", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "illo expedita consequatur quia in", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "quo adipisci enim quam ut ab", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "molestiae perspiciatis ipsa", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "illo est ratione doloremque quia maiores aut", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "vero rerum temporibus dolor", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "ipsa repellendus fugit nisi", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "et doloremque nulla", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "repellendus sunt dolores architecto voluptatum", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "ab voluptatum amet voluptas", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "accusamus eos facilis sint et aut voluptatem", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "quo laboriosam deleniti aut qui", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "dolorum est consequatur ea mollitia in culpa", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "molestiae ipsa aut voluptatibus pariatur dolor nihil", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "ullam nobis libero sapiente ad optio sint", "completed": true}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "suscipit repellat esse quibusdam voluptatem incidunt", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "distinctio vitae autem nihil ut molestias quo", "completed": true}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "et itaque necessitatibus maxime molestiae qui quas velit", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "adipisci non ad dicta qui amet quaerat doloribus ea", "completed": false}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle": "voluptas quo tenetur perspiciatis explicabo natus", "completed": true}
# {"userName": "Antonette", "email": "Shanna@melissa.tv", "todoTitle":
", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "ut cupiditate sequi aliquam fuga maiores", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "inventore saepe cumque et aut illum enim", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "omnis nulla eum aliquam distinctio", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "molestias modi perferendis perspiciatis", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "voluptates dignissimos sed doloribus animi quaerat aut", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "explicabo odio est et", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "consequuntur animi possimus", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "vel non beatae est", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "culpa eius et voluptatem et", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "accusamus sint iusto et voluptatem exercitationem", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "temporibus atque distinctio omnis eius impedit tempore molestias pariatur", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "ut quas possimus exercitationem sint voluptates", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "rerum debitis voluptatem qui eveniet tempora distinctio a", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "sed ut vero sit molestiae", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "rerum ex veniam mollitia voluptatibus pariatur", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "consequuntur aut ut fugit similique", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "dignissimos quo nobis earum saepe", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "quis eius est sint explicabo", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "numquam repellendus a magnam", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "ipsam aperiam voluptates qui", "completed": false}
#
# ################

# %% [markdown]
# **Approach 3:**

# %%
#!/usr/local/bin/python3
#
#
#mchilty@gmail.com 
#
#Collects and harmonizes oddball Latin homework completion status using 2 different approaches from:
#
#https://jsonplaceholder.typicode.com/users
#https://jsonplaceholder.typicode.com/todos
#https://jsonplaceholder.typicode.com/users/1
#
#
#Output example:
#{"userName": "Bret", "email": "Sincere@april.biz", "todoTitle":"delectus aut autem", "completed": false}
#
#configure the proxy as suits your needs or remove related arguments
#
#

import json
import os
import requests

os.environ['REQUESTS_CA_BUNDLE'] = "/Users/mchilty/burpCAcert.pem"
proxies = {"http": "http://127.0.0.1:8080", "https": "http://127.0.0.1:8080"}
headers = {'User-Agent': 'mchilty-0.1'}

users_url = ("https://jsonplaceholder.typicode.com/users")
todos_url = ("https://jsonplaceholder.typicode.com/todos")
users_todos_url = ("https://jsonplaceholder.typicode.com/users/$id/todos")

users_response = requests.get(users_url, headers=headers, proxies=proxies)
todos_response = requests.get(todos_url, headers=headers, proxies=proxies)

users_response_data = users_response.json()
todos_response_data = todos_response.json()

print("Using the following API endpoints:")
print(users_url)
print(todos_url)
print(users_todos_url)
print(todos_url)
print()
#		
#uses the data returned by /users and fetches the todo data path from /users/$id/todos using subsequent API requests 
#
user_extract = {}
for user in users_response_data:
		userId = (user['id'])
		username = (user['username'])
		email = (user['email'])
		users_todos_url = (users_url + "/" + str(user['id']) + "/todos")
		users_todos_response = requests.get(users_todos_url, headers=headers, proxies=proxies)
		users_todo_response_data = users_todos_response.json()
		
		for todo in users_todo_response_data:
			title = (todo['title'])
			completed = (todo['completed'])		
			user_extract['userName'] = username
			user_extract['email'] = email
			user_extract['todoTitle'] = title
			user_extract['completed'] = completed
			user_extract_json_data = json.dumps(user_extract)	
			print(user_extract_json_data)

print()
print("################")
print()
# Out:
# Using the following API endpoints:
# https://jsonplaceholder.typicode.com/users
# https://jsonplaceholder.typicode.com/todos
# https://jsonplaceholder.typicode.com/users/$id/todos
# https://jsonplaceholder.typicode.com/todos
#
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "delectus aut autem", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "quis ut nam facilis et officia qui", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "fugiat veniam minus", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "et porro tempora", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "laboriosam mollitia et enim quasi adipisci quia provident illum", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "qui ullam ratione quibusdam voluptatem quia omnis", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "illo expedita consequatur quia in", "completed": false}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "quo adipisci enim quam ut ab", "completed": true}
# {"userName": "Bret", "email": "Sincere@april.biz", "todoTitle": "molesti
"completed": false}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "ut eum exercitationem sint", "completed": false}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "beatae qui ullam incidunt voluptatem non nisi aliquam", "completed": false}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "molestiae suscipit ratione nihil odio libero impedit vero totam", "completed": true}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "eum itaque quod reprehenderit et facilis dolor autem ut", "completed": true}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "esse quas et quo quasi exercitationem", "completed": false}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "animi voluptas quod perferendis est", "completed": false}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "eos amet tempore laudantium fugit a", "completed": false}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "accusamus adipisci dicta qui quo ea explicabo sed vero", "completed": true}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "odit eligendi recusandae doloremque cumque non", "completed": false}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "ea aperiam consequatur qui repellat eos", "completed": false}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "rerum non ex sapiente", "completed": true}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "voluptatem nobis consequatur et assumenda magnam", "completed": true}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "nam quia quia nulla repellat assumenda quibusdam sit nobis", "completed": true}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "dolorem veniam quisquam deserunt repellendus", "completed": true}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "debitis vitae delectus et harum accusamus aut deleniti a", "completed": true}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis", "completed": true}
# {"userName": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "todoTitle": "et praesentium aliquam est", "completed": false}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "ex hic consequuntur earum omnis alias ut occaecati culpa", "completed": true}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "omnis laboriosam molestias animi sunt dolore", "completed": true}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "natus corrupti maxime laudantium et voluptatem laboriosam odit", "completed": false}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "reprehenderit quos aut aut consequatur est sed", "completed": false}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "fugiat perferendis sed aut quidem", "completed": false}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "quos quo possimus suscipit minima ut", "completed": false}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "et quis minus quo a asperiores molestiae", "completed": false}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "recusandae quia qui sunt libero", "completed": false}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "ea odio perferendis officiis", "completed": true}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "quisquam aliquam quia doloribus aut", "completed": false}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "fugiat aut voluptatibus corrupti deleniti velit iste odio", "completed": true}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "et provident amet rerum consectetur et voluptatum", "completed": false}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "harum ad aperiam quis", "completed": false}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "similique aut quo", "completed": false}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "laudantium eius officia perferendis provident perspiciatis asperiores", "completed": true}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "magni soluta corrupti ut maiores rem quidem", "completed": false}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "et placeat temporibus voluptas est tempora quos quibusdam", "completed": false}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "nesciunt itaque commodi tempore", "completed": true}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "omnis consequuntur cupiditate impedit itaque ipsam quo", "completed": true}
# {"userName": "Delphine", "email": "Chaim_McDermott@dana.io", "todoTitle": "debitis nisi et dolorem repellat et", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "ut cupiditate sequi aliquam fuga maiores", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "inventore saepe cumque et aut illum enim", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "omnis nulla eum aliquam distinctio", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "molestias modi perferendis perspiciatis", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "voluptates dignissimos sed doloribus animi quaerat aut", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "explicabo odio est et", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "consequuntur animi possimus", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "vel non beatae est", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "culpa eius et voluptatem et", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "accusamus sint iusto et voluptatem exercitationem", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "temporibus atque distinctio omnis eius impedit tempore molestias pariatur", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "ut quas possimus exercitationem sint voluptates", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "rerum debitis voluptatem qui eveniet tempora distinctio a", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "sed ut vero sit molestiae", "completed": false}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "rerum ex veniam mollitia voluptatibus pariatur", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "consequuntur aut ut fugit similique", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "dignissimos quo nobis earum saepe", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "quis eius est sint explicabo", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "numquam repellendus a magnam", "completed": true}
# {"userName": "Moriah.Stanton", "email": "Rey.Padberg@karina.biz", "todoTitle": "ipsam aperiam voluptates qui", "completed": false}
#
# ################

# %% [markdown]
# The JSONPlaceholder API challenge was a great opportunity to experiment with different techniques for interacting with the API and harmonizing the data about todo completion status.  I arrived at this stage of development using Python interpreter and emacs, followed by BBedit and finally into VSCode and Github.  VSCode made creating the Jupyter Notebook simple and it seemed like a good way to convey the outcomes, outputs, and the though process.  Online resources most frequestly used were Stack Overflow, reddit, numerous one-off how-to writeups and otherwise. No IDE code building Fu or generative AI and it started out (and remains) clunky and in need of refactoring.
